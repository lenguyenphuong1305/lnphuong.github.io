# %%
import pandas as pd
import xlrd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn import preprocessing
import pickle 
from sklearn.metrics import mean_squared_error, r2_score

# %%
read_xls=pd.read_excel('tinhdiemtb.xlsx')
val_xls=read_xls.values

# %%
feature=np.array(val_xls[:,9:64],dtype=np.float32)
label=np.array(val_xls[:,64:65],dtype=np.float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(feature, label, test_size=0.2)
model=linear_model.LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
new_model=linear_model.LinearRegression()
filename = 'mymodel.sav'
new_model=pickle.load(open(filename, 'rb'))

# %%
print(x_test.shape)
ketqua_nhieu=model.predict(x_test)
print(ketqua_nhieu.shape)
# Out:
# (263, 55)
# (263, 1)

# %%
arr=x_test[6]
test=np.expand_dims(arr,axis=0) # *
print(test.shape)
ketqua_mot=model.predict(test)
print(ketqua_mot.shape)
# Out:
# (1, 55)
# (1, 1)

# %%
print(ketqua_mot)
if   (ketqua_mot <= 2.1): 
     print('rat thap')
elif (ketqua_mot <= 2.8):
     print('thap')
elif (ketqua_mot <= 3.5): 
     print('trung binh')
elif (ketqua_mot <= 4.2):
     print('cao')
else:
     print('rat cao')
# Out:
# [[2.9818182]]
# trung binh

# %%
print(ketqua_mot.shape)
print(ketqua_nhieu.shape)
print(ketqua_mot)
print(ketqua_nhieu)
# Out:
# (1, 1)
# (263, 1)
# [[2.9818182]]
# [[3.4909089]
#  [2.9272726]
#  [2.781818 ]
#  [2.9636364]
#  [3.1636364]
#  [2.9636364]
#  [2.9818182]
#  [3.418182 ]
#  [3.145455 ]
#  [3.1454544]
#  [2.9272726]
#  [2.9454546]
#  [3.1636362]
#  [3.9636369]
#  [3.2545457]
#  [2.8909092]
#  [3.0363638]
#  [3.0545454]
#  [3.3636365]
#  [3.1636362]
#  [3.545455 ]
#  [3.0363636]
#  [4.29091  ]
#  [4.2363644]
#  [3.1090913]
#  [3.1636362]
#  [2.8181815]
#  [2.8727274]
#  [2.7636366]
#  [2.9454544]
#  [4.036364 ]
#  [3.272727 ]
#  [3.3636365]
#  [3.3454547]
#  [3.036364 ]
#  [3.0363636]
#  [3.636364 ]
#  [4.181819 ]
#  [2.909091 ]
#  [3.327273 ]
#  [2.872727 ]
#  [3.109091 ]
#  [3.1272726]
#  [4.1090918]
#  [2.7999997]
#  [3.327273 ]
#  [3.1636367]
#  [3.2181816]
#  [3.4727273]
#  [3.236364 ]
#  [2.9090908]
#  [3.8909097]
#  [3.545455 ]
#  [3.0727272]
#  [3.0727272]
#  [3.1454544]
#  [3.309091 ]
#  [2.7636364]
#  [3.4545453]
#  [3.109091 ]
#  [3.3636365]
#  [2.9818182]
#  [2.8363636]
#  [2.8545456]
#  [2.7272727]
#  [2.8363636]
#  [3.0545456]
#  [2.9999998]
#  [3.509091 ]
#  [2.981818 ]
#  [3.0727272]
#  [3.0363634]
#  [3.4      ]
#  [3.1636367]
#  [3.2909093]
#  [2.7272727]
#  [3.2909093]
#  [3.018182 ]
#  [2.9818182]
#  [3.3454547]
#  [3.0363636]
#  [2.909091 ]
#  [2.9999998]
#  [3.0363636]
#  [2.981818 ]
#  [2.981818 ]
#  [2.8363636]
#  [3.0363638]
#  [3.       ]
#  [2.9818182]
#  [3.090909 ]
#  [2.6545453]
#  [3.4727273]
#  [3.1636362]
#  [3.0545454]
#  [3.9272733]
#  [2.9636364]
#  [2.527273 ]
#  [3.1454544]
#  [2.909091 ]
#  [3.090909 ]
#  [3.8181822]
#  [3.1090908]
#  [3.2181818]
#  [3.5090911]
#  [3.7636366]
#  [2.8000002]
#  [3.0363636]
#  [3.2000003]
#  [2.9818182]
#  [3.7818189]
#  [3.2909093]
#  [2.9818182]
#  [3.218182 ]
#  [3.2727275]
#  [2.7454545]
#  [2.8727274]
#  [3.2363634]
#  [3.0181818]
#  [3.2909093]
#  [2.9818182]
#  [3.090909 ]
#  [2.8909087]
#  [3.2727275]
#  [4.29091  ]
#  [2.8727274]
#  [3.0363638]
#  [3.309091 ]
#  [2.7454548]
#  [3.0909092]
#  [3.272727 ]
#  [3.2363636]
#  [4.0000005]
#  [3.4      ]
#  [3.2363634]
#  [3.0727274]
#  [3.3454547]
#  [3.7090914]
#  [3.2545457]
#  [3.0181818]
#  [2.981818 ]
#  [3.1636362]
#  [2.9818182]
#  [2.7272727]
#  [3.236364 ]
#  [3.4727273]
#  [2.7272727]
#  [2.9818182]
#  [3.1454544]
#  [3.945455 ]
#  [3.2545457]
#  [3.490909 ]
#  [2.8727274]
#  [3.6000004]
#  [3.309091 ]
#  [3.2181818]
#  [3.9636369]
#  [2.781818 ]
#  [3.1636362]
#  [3.0909095]
#  [3.1090908]
#  [3.2000003]
#  [2.8727274]
#  [3.0545454]
#  [4.0363646]
#  [4.6181827]
#  [2.9818182]
#  [3.5818183]
#  [3.0363636]
#  [3.2545457]
#  [2.909091 ]
#  [3.2909095]
#  [3.2545457]
#  [4.1272736]
#  [3.8727276]
#  [3.1090908]
#  [2.9636364]
#  [3.3818183]
#  [3.272727 ]
#  [2.890909 ]
#  [3.0363638]
#  [2.9272726]
#  [3.0545459]
#  [3.4363637]
#  [3.0909095]
#  [3.3636365]
#  [3.090909 ]
#  [3.4545455]
#  [4.0909095]
#  [4.0545464]
#  [3.6727276]
#  [3.4363632]
#  [3.1636367]
#  [2.581818 ]
#  [2.8363638]
#  [3.0181818]
#  [2.781818 ]
#  [2.6545453]
#  [3.7636366]
#  [3.0181818]
#  [3.2909093]
#  [3.0363636]
#  [2.927273 ]
#  [2.9818182]
#  [3.0727272]
#  [3.7818184]
#  [3.4      ]
#  [2.8363638]
#  [3.8363638]
#  [2.7636366]
#  [2.9272728]
#  [3.181818 ]
#  [2.9272728]
#  [3.018182 ]
#  [3.109091 ]
#  [4.0181828]
#  [3.8181822]
#  [3.218182 ]
#  [3.090909 ]
#  [3.2545457]
#  [3.090909 ]
#  [3.0181823]
#  [3.181818 ]
#  [3.3818183]
#  [3.1090913]
#  [3.9090915]
#  [3.1454544]
#  [2.9454544]
#  [3.1818182]
#  [2.9636364]
#  [2.9818184]
#  [2.8181818]
#  [3.1454546]
#  [3.2545455]
#  [2.7818182]
#  [3.4363637]
#  [3.290909 ]
#  [3.181818 ]
#  [2.6545453]
#  [3.145455 ]
#  [3.2363636]
#  [3.1818185]
#  [3.2727273]
#  [3.1818185]
#  [2.8909092]
#  [3.0727272]
#  [2.9272726]
#  [4.2181826]
#  [2.909091 ]
#  [3.181818 ]
#  [3.4181821]
#  [3.0727272]
#  [2.8727272]
#  [3.9454548]
#  [3.7818184]
#  [3.1272728]
#  [3.0545454]
#  [3.1272726]
#  [3.       ]
#  [3.090909 ]
#  [3.236364 ]
#  [3.2363634]
#  [3.1454546]]
